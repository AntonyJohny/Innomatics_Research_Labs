# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonyJohny/Innomatics_Research_Labs/blob/main/GenAi/Task_1/GenAi_Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langchain langchain-community requests==2.32.4
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 68.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.1/459.1 kB 28.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 5.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-classic 1.0.3 requires langchain-core<2.0.0,>=1.2.19, but you have langchain-core 0.3.84 which is incompatible.
# langchain-classic 1.0.3 requires langchain-text-splitters<2.0.0,>=1.1.1, but you have langchain-text-splitters 0.3.11 which is incompatible.
# langgraph-prebuilt 1.0.8 requires langchain-core>=1.0.0, but you have langchain-core 0.3.84 which is incompatible.

# %% [markdown]
# **Task 1: Replace Hardcoded Prompts**

# %%
from langchain_core.prompts import PromptTemplate

# Task 1: Converting hardcoded function to LangChain Template
template_1 = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)

# Example usage
print(template_1.format(topic="Quantum Computing"))
# Out:
# Explain Quantum Computing in simple terms for beginners

# %% [markdown]
# **Task 2: Multi-Input Prompt System**

# %%
# Task 2: Multi-Input System
template_2 = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

test_cases = [
    {"topic": "AI", "audience": "beginners", "tone": "friendly"},
    {"topic": "Python", "audience": "kids", "tone": "fun"},
    {"topic": "Deep Learning", "audience": "engineers", "tone": "technical"}
]

for case in test_cases:
    print(template_2.format(**case))
# Out:
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Deep Learning for engineers in a technical tone

# %% [markdown]
# **Task 3: Prompt Variations Engine**

# %%
# Task 3: Variations
teaching_template = PromptTemplate.from_template("Explain {topic} clearly step by step")
interview_template = PromptTemplate.from_template("Ask 3 questions about {topic}")
story_template = PromptTemplate.from_template("Explain {topic} as a story")

topic = "Machine Learning"
print(teaching_template.format(topic=topic))
print(interview_template.format(topic=topic))
print(story_template.format(topic=topic))
# Out:
# Explain Machine Learning clearly step by step
# Ask 3 questions about Machine Learning
# Explain Machine Learning as a story

# %% [markdown]
# **Task 4: ChatPromptTemplate System**

# %%
from langchain_core.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate

# Task 4: Chat-based prompts
def get_chat_prompt(role, topic):
    roles = {
        "teacher": "You are a helpful teaching assistant.",
        "interviewer": "You are a professional technical interviewer.",
        "motivator": "You are an inspiring mentor and motivator."
    }

    system_message = SystemMessagePromptTemplate.from_template(roles.get(role, "You are a helpful assistant."))
    human_message = HumanMessagePromptTemplate.from_template("Tell me about {topic}")

    chat_template = ChatPromptTemplate.from_messages([system_message, human_message])
    return chat_template.format_prompt(topic=topic).to_messages()

print(get_chat_prompt("teacher", "Neural Networks"))
# Out:
# [SystemMessage(content='You are a helpful teaching assistant.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Tell me about Neural Networks', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# **Task 5 & 6: Validation & Generator App**

# %%
# Task 5: Validation Layer
def validate_inputs(audience, tone):
    valid_audiences = ["beginner", "intermediate", "expert"]
    valid_tones = ["formal", "casual", "fun"]

    # Validation logic with default fallbacks
    final_audience = audience if audience in valid_audiences else "beginner"
    final_tone = tone if tone in valid_tones else "formal"

    return final_audience, final_tone

# Task 6: Prompt Generator App
def generate_prompt(topic, audience, tone, style):
    # Validate first
    v_audience, v_tone = validate_inputs(audience, tone)

    styles = {
        "teaching": "Explain {topic} for {audience} in a {tone} teaching style.",
        "interview": "Generate interview questions on {topic} for an {audience} level in a {tone} tone.",
        "storytelling": "Explain {topic} for {audience} in a {tone} storytelling style."
    }

    prompt_temp = PromptTemplate.from_template(styles.get(style, styles["teaching"]))
    return prompt_temp.format(topic=topic, audience=v_audience, tone=v_tone)

# Example Output
print(generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))
# Out:
# Explain Neural Networks for beginner in a fun storytelling style.

# %% [markdown]
# **Task 7: Template Reusability Test**

# %%
# Task 7: Reusability Test
reusable_template = PromptTemplate.from_template("Research Summary: Subject: {topic}, Level: {audience}")

inputs = [
    {"topic": "Blockchain", "audience": "CEO"},
    {"topic": "Photosynthesis", "audience": "5th Grader"},
    {"topic": "Rust Programming", "audience": "C++ Developer"},
    {"topic": "Yoga", "audience": "Seniors"},
    {"topic": "Black Holes", "audience": "Astrophysicists"}
]

for inp in inputs:
    print(reusable_template.format(**inp))
# Out:
# Research Summary: Subject: Blockchain, Level: CEO
# Research Summary: Subject: Photosynthesis, Level: 5th Grader
# Research Summary: Subject: Rust Programming, Level: C++ Developer
# Research Summary: Subject: Yoga, Level: Seniors
# Research Summary: Subject: Black Holes, Level: Astrophysicists
